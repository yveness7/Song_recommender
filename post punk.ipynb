# %%
#Loading credentials from the config file

# %%
import config

# %%
#Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
import pprint

# %%
#searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "50QVTeydNdJRVbvRJdmEhQ",market="GB") 
#we copy the link from the paylist

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/50QVTeydNdJRVbvRJdmEhQ/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-07-21T21:40:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31aihyfrkbvwt22ib7zwnyacai5i'},
#     'href': 'https://api.spotify.com/v1/users/31aihyfrkbvwt22ib7zwnyacai5i',
#     'id': '31aihyfrkbvwt22ib7zwnyacai5i',
#     'type': 'user',
#     'uri': 'spotify:user:31aihyfrkbvwt22ib7zwnyacai5i'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hpTA4ta9iSezFWhwfEbWK'},
#        'href': 'https://api.spotify.com/v1/artists/7hpTA4ta9iSezFWhwfEbWK',
#        'id': '7hpTA4ta9iSezFWhwfEbWK',
#        'name': 'Casket Cassette',
#        'type': 'artist',
#        'uri': 'spotify:artist:7hpTA4ta9iSezFWhwfEbWK'}],
# ...

# %%
type(playlist)
# Out:
# dict

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["items"][0]
# Out:
# {'added_at': '2022-07-21T21:40:30Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31aihyfrkbvwt22ib7zwnyacai5i'},
#   'href': 'https://api.spotify.com/v1/users/31aihyfrkbvwt22ib7zwnyacai5i',
#   'id': '31aihyfrkbvwt22ib7zwnyacai5i',
#   'type': 'user',
#   'uri': 'spotify:user:31aihyfrkbvwt22ib7zwnyacai5i'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hpTA4ta9iSezFWhwfEbWK'},
#      'href': 'https://api.spotify.com/v1/artists/7hpTA4ta9iSezFWhwfEbWK',
#      'id': '7hpTA4ta9iSezFWhwfEbWK',
#      'name': 'Casket Cassette',
#      'type': 'artist',
#      'uri': 'spotify:artist:7hpTA4ta9iSezFWhwfEbWK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0wPA6LVuz3NAJr7WtZbUNl'},
#    'href': 'https://api.spotify.com/v1/albums/0wPA6LVuz3NAJr7WtZbUNl',
#    'id': '0wPA6LVuz3NAJr7WtZbUNl',
# ...

# %%
#extract a song from a playlist

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/50QVTeydNdJRVbvRJdmEhQ/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-07-21T21:40:30Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31aihyfrkbvwt22ib7zwnyacai5i'},
#                          'href': 'https://api.spotify.com/v1/users/31aihyfrkbvwt22ib7zwnyacai5i',
#                          'id': '31aihyfrkbvwt22ib7zwnyacai5i',
#                          'type': 'user',
#                          'uri': 'spotify:user:31aihyfrkbvwt22ib7zwnyacai5i'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hpTA4ta9iSezFWhwfEbWK'},
#                                              'href': 'https://api.spotify.com/v1/artists/7hpTA4ta9iSezFWhwfEbWK',
# ...

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '6X3M5CllCtAjKVkL3vnqlQ'

# %%
from IPython.display import IFrame
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song(playlist["items"][0]["track"]["id"])
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/6X3M5CllCtAjKVkL3vnqlQ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## ok let's go now

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# ## post punk

# %%
post_punk = get_playlist_tracks('Spotify','50QVTeydNdJRVbvRJdmEhQ')

# %%
post_punk
# Out:
# [{'added_at': '2022-07-21T21:40:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31aihyfrkbvwt22ib7zwnyacai5i'},
#    'href': 'https://api.spotify.com/v1/users/31aihyfrkbvwt22ib7zwnyacai5i',
#    'id': '31aihyfrkbvwt22ib7zwnyacai5i',
#    'type': 'user',
#    'uri': 'spotify:user:31aihyfrkbvwt22ib7zwnyacai5i'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hpTA4ta9iSezFWhwfEbWK'},
#       'href': 'https://api.spotify.com/v1/artists/7hpTA4ta9iSezFWhwfEbWK',
#       'id': '7hpTA4ta9iSezFWhwfEbWK',
#       'name': 'Casket Cassette',
#       'type': 'artist',
#       'uri': 'spotify:artist:7hpTA4ta9iSezFWhwfEbWK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0wPA6LVuz3NAJr7WtZbUNl'},
#     'href': 'https://api.spotify.com/v1/albums/0wPA6LVuz3NAJr7WtZbUNl',
#     'id': '0wPA6LVuz3NAJr7WtZbUNl',
# ...

# %%
post_punk_ids = []
for i in post_punk:
    post_punk_ids.append(i['track']['id'])

# %%
post_punk_ids
# Out:
# ['6X3M5CllCtAjKVkL3vnqlQ',
#  '3mztR2jv7VaNccNo1cEIHw',
#  '6sShc4tkAu2OMULhdtb7dK',
#  '04xdNNpZBwXtZKfUTxdU3I',
#  '5KzYPziILXOr9Ww5r4PIDM',
#  '4olsMaLbdIBrk2Iwq0s00V',
#  '1K3MgcOvkB31JH2apPVLeG',
#  '3BjFcVP5mCRocHRuz1JeT5',
#  '0LO5lEv8Pc7FlyuhC1tfHl',
#  '6HNnnz4Uo1DZCUTVXmH95d',
#  '45wU0gt5K1RGPGqfhP71Vx',
#  '0qesV7nklv3s8rq8J61NhM',
#  '7vvultYHYCuFk0AJWa5c9O',
#  '0hsfHBwHwrKEMJn0xTrbFs',
#  '44f0f4yJmFIGKQqxX2heUi',
#  '4F0lvDZ2pWl6fcNRvXSeQy',
#  '4eU2yAaJ64J2oft5pl8vwk',
#  '5emsHiwPQwRoI2NXDR3eAj',
#  '33hEWEZGWuaYr64MWquDnP',
#  '4zcVHb29WjQmc2qKVFuyfz',
#  '7MqmxzdudJYyxwF8gXWwHH',
#  '3mQHJVztkabAFNvegubRDB',
#  '0IgkK7b1STVdwotBrtOlzl',
#  '144GkinGtFjrA5A2O04MA5',
#  '7vIFHpoofIaZuh3CsdTuTT',
#  '5FcoPwAN6Jsu7wh731Kwhp',
#  '7yQbHXCnBieG8tLJj1SEiW',
#  '2sAp8fbeTgikm6dDVsEeiV',
#  '3MlguQSsgg3uN56DjjzVgy',
#  '4bgPDf0OLHytRSicJ8y9pa',
#  '2kC1oOz2pn0E2ARyn7opcU',
#  '2lanF1CHU4SjNkTc1msuGK',
#  '7n3Y93fkz1oRdsgpYTazkh',
#  '7EzsU6MrB1vTgs4Q8LCobR',
# ...

# %%
#audio_features(tracks=[])

    #Get audio features for one or multiple tracks based upon their Spotify IDs Parameters:

            #tracks - a list of track URIs, URLs or IDs, maximum: 100 ids

# %%
#for i in post_punk_ids:
    #post_punk_af.append(sp.audio_features()[0])
    
    
    #end = i + chunk
    #chunk_ids = post_punk_ids[start:end]
    #chunk_features = sp.audio_features(tracks=chunk_ids)
    
    
#post_punk_af.extend(chunk_features)

# %%
#post_punk_af = []
chunk = 100 
post_punk_ids_chopped = [post_punk_ids[i:i+chunk] for i in range(0,len(post_punk_ids),100)]

# %%
post_punk_af = []
for i in post_punk_ids_chopped:
    try:
        post_punk_af.extend(sp.audio_features(i))
    except:
        pass
post_punk_df = pd.DataFrame(post_punk_af)
post_punk_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.450   0.837    1    -5.312     1       0.0346      0.000008
# 1           0.414   0.694    1   -11.366     1       0.0473      0.000086
# 2           0.502   0.924    0    -6.315     1       0.0375      0.462000
# 3           0.524   0.850    6    -5.541     0       0.0461      0.000007
# 4           0.717   0.400    0    -9.898     1       0.1240      0.140000
# ..            ...     ...  ...       ...   ...          ...           ...
# 297         0.588   0.820   10    -5.933     1       0.0416      0.074900
# 298         0.520   0.929    0    -4.716     0       0.0350      0.057800
# 299         0.522   0.650    0   -12.970     0       0.0322      0.020600
# 300         0.512   0.917    4    -9.833     0       0.0313      0.002260
# 301         0.749   0.907    1    -3.790     0       0.0543      0.704000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
post_punk_df.to_csv('post_punk.csv')

# %% [markdown]
# ## stoner rock

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
'37i9dQZF1DXdpVGstUksUC'
# Out:
# '37i9dQZF1DXdpVGstUksUC'

# %%
stoner_rock = get_playlist_tracks('Spotify','37i9dQZF1DXdpVGstUksUC')

# %%
stoner_rock_ids = []
for i in stoner_rock:
    stoner_rock_ids.append(i['track']['id'])

# %%
chunk = 100 
stoner_rock_ids_chopped = [stoner_rock_ids[i:i+chunk] for i in range(0,len(stoner_rock_ids),100)]

# %%
stoner_rock_af = []
for i in stoner_rock_ids_chopped:
    try:
        stoner_rock_af.extend(sp.audio_features(i))
    except:
        pass
stoner_rock_df = pd.DataFrame(stoner_rock_af)
stoner_rock_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.172   0.904   11    -4.831     1       0.0586      0.000054
# 1          0.437   0.390    9    -9.944     1       0.0460      0.630000
# 2          0.237   0.691    0    -8.148     0       0.0420      0.005850
# 3          0.180   0.419    5   -13.268     1       0.0308      0.000127
# 4          0.455   0.919   11    -4.656     1       0.0383      0.000713
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.311   0.832    7    -5.139     1       0.0368      0.000029
# 96         0.380   0.691    1    -7.790     0       0.0335      0.001560
# 97         0.168   0.813    1    -6.856     1       0.0510      0.000361
# 98         0.460   0.756    5    -9.251     0       0.0426      0.037100
# 99         0.538   0.863    4    -6.123     0       0.1390      0.004950
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
stoner_rock_df.to_csv('stoner_rock.csv')

# %% [markdown]
# ## vaporwave

# %%
'37i9dQZF1DWU4EQPjP9ZpS'

# %%
vaporwave = get_playlist_tracks('Spotify','37i9dQZF1DWU4EQPjP9ZpS')
vaporwave_ids = []
for i in vaporwave:
    vaporwave_ids.append(i['track']['id'])
    
chunk = 100 
vaporwave_ids_chopped = [vaporwave_ids[i:i+chunk] for i in range(0,len(vaporwave_ids),100)]

vaporwave_af = []
for i in vaporwave_ids_chopped:
    try:
        vaporwave_af.extend(sp.audio_features(i))
    except:
        pass
vaporwave_df = pd.DataFrame(vaporwave_af)
vaporwave_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.497   0.850    6    -6.039     0       0.0279      0.012200
# 1          0.680   0.727    5   -11.867     0       0.0862      0.477000
# 2          0.388   0.898    2    -6.403     0       0.1860      0.194000
# 3          0.481   0.727    0   -11.452     1       0.0407      0.021300
# 4          0.345   0.419    8   -15.063     0       0.2130      0.000404
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.628   0.803    0    -7.562     0       0.0361      0.014900
# 96         0.639   0.418    1   -13.352     1       0.0315      0.006830
# 97         0.645   0.767    2    -8.516     1       0.0393      0.460000
# 98         0.633   0.723    5   -10.101     0       0.0436      0.142000
# 99         0.692   0.740    0   -10.589     1       0.0398      0.020000
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
vaporwave_df.to_csv('vaporwave.csv')

# %% [markdown]
# ## surfrock

# %%
'7p04wkFtiIJTAVsFUFzE6q'

# %%
surfrock = get_playlist_tracks('Spotify','7p04wkFtiIJTAVsFUFzE6q')
surfrock_ids = []
for i in surfrock:
    surfrock_ids.append(i['track']['id'])
    
chunk = 100 
surfrock_ids_chopped = [surfrock_ids[i:i+chunk] for i in range(0,len(surfrock_ids),100)]

surfrock_af = []
for i in surfrock_ids_chopped:
    try:
        surfrock_af.extend(sp.audio_features(i))
    except:
        pass
surfrock_df = pd.DataFrame(surfrock_af)
surfrock_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.619   0.754   11    -8.547     0       0.0288      0.056300
# 1           0.426   0.921    2    -2.469     1       0.0529      0.000793
# 2           0.582   0.571   10    -5.559     0       0.0314      0.817000
# 3           0.458   0.919    4    -7.882     0       0.0311      0.174000
# 4           0.477   0.828   11   -12.964     0       0.0569      0.252000
# ..            ...     ...  ...       ...   ...          ...           ...
# 202         0.285   0.876    9    -2.964     0       0.0429      0.000021
# 203         0.658   0.953    4    -4.356     0       0.0302      0.521000
# 204         0.536   0.968    1    -4.427     0       0.0448      0.040600
# 205         0.503   0.610    9   -13.397     1       0.0583      0.323000
# 206         0.110   0.702    9   -13.590     0       0.0864      0.045000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
surfrock_df.to_csv('surfrock.csv')

# %% [markdown]
# ## post_metal

# %%
'7HPigooLkKvn3Enr5ilQwS'
# Out:
# '7HPigooLkKvn3Enr5ilQwS'

# %%
post_metal = get_playlist_tracks('Spotify','7p04wkFtiIJTAVsFUFzE6q')
post_metal_ids = []
for i in post_metal:
    post_metal_ids.append(i['track']['id'])
    
chunk = 100 
post_metal_ids_chopped = [post_metal_ids[i:i+chunk] for i in range(0,len(post_metal_ids),100)]

post_metal_af = []
for i in post_metal_ids_chopped:
    try:
        post_metal_af.extend(sp.audio_features(i))
    except:
        pass
post_metal_df = pd.DataFrame(post_metal_af)
post_metal_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.619   0.754   11    -8.547     0       0.0288      0.056300
# 1           0.426   0.921    2    -2.469     1       0.0529      0.000793
# 2           0.582   0.571   10    -5.559     0       0.0314      0.817000
# 3           0.458   0.919    4    -7.882     0       0.0311      0.174000
# 4           0.477   0.828   11   -12.964     0       0.0569      0.252000
# ..            ...     ...  ...       ...   ...          ...           ...
# 202         0.285   0.876    9    -2.964     0       0.0429      0.000021
# 203         0.658   0.953    4    -4.356     0       0.0302      0.521000
# 204         0.536   0.968    1    -4.427     0       0.0448      0.040600
# 205         0.503   0.610    9   -13.397     1       0.0583      0.323000
# 206         0.110   0.702    9   -13.590     0       0.0864      0.045000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
post_metal_df.to_csv('post_metal.csv')

# %% [markdown]
# ## indie

# %%
'2zn5Uz49wyfb5RvIPxgify'
# Out:
# '2zn5Uz49wyfb5RvIPxgify'

# %%
indie = get_playlist_tracks('Spotify','2zn5Uz49wyfb5RvIPxgify')
indie_ids = []
for i in indie:
    indie_ids.append(i['track']['id'])
    
chunk = 100 
indie_ids_chopped = [indie_ids[i:i+chunk] for i in range(0,len(indie_ids),100)]

indie_af = []
for i in indie_ids_chopped:
    try:
        indie_af.extend(sp.audio_features(i))
    except:
        pass
indie_df = pd.DataFrame(indie_af)
indie_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.654   0.828    1    -5.377     0       0.0281      0.001460
# 1           0.405   0.783    8    -5.408     1       0.0404      0.003060
# 2           0.590   0.829    0    -5.649     1       0.0419      0.060100
# 3           0.546   0.878    7    -5.137     1       0.0525      0.013300
# 4           0.277   0.663    4    -8.821     0       0.0377      0.000409
# ..            ...     ...  ...       ...   ...          ...           ...
# 194         0.429   0.924    2    -6.131     0       0.0406      0.000542
# 195         0.548   0.865    0    -5.325     1       0.0302      0.001710
# 196         0.429   0.946    0    -5.806     1       0.0720      0.580000
# 197         0.263   0.900    9    -6.069     1       0.0486      0.002010
# 198         0.345   0.785    7    -4.989     1       0.0437      0.001650
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
indie_df.to_csv('indie.csv')

# %% [markdown]
# ## sludge

# %%
'32T7VoaTELJS5FU1mIIa6w'
# Out:
# '32T7VoaTELJS5FU1mIIa6w'

# %%
sludge = get_playlist_tracks('Spotify','32T7VoaTELJS5FU1mIIa6w')
sludge_ids = []
for i in sludge:
    sludge_ids.append(i['track']['id'])
    
chunk = 100 
sludge_ids_chopped = [sludge_ids[i:i+chunk] for i in range(0,len(sludge_ids),100)]

sludge_af = []
for i in sludge_ids_chopped:
    try:
        sludge_af.extend(sp.audio_features(i))
    except:
        pass
sludge_df = pd.DataFrame(sludge_af)
sludge_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.3460   0.862    1    -6.073     1       0.0651      0.001210
# 1          0.2190   0.861    6    -4.460     0       0.0440      0.000248
# 2          0.1990   0.944    1    -5.262     1       0.0939      0.000096
# 3          0.1520   0.800    7    -7.655     1       0.0584      0.000191
# 4          0.1550   0.921    8    -5.993     1       0.0717      0.000013
# ..            ...     ...  ...       ...   ...          ...           ...
# 150        0.1960   0.782    4    -6.533     0       0.0641      0.000005
# 151        0.2050   0.720    5    -7.592     1       0.0415      0.000004
# 152        0.0906   0.864    7    -5.545     1       0.0849      0.000002
# 153        0.0832   0.939    4    -4.496     0       0.0701      0.000094
# 154        0.2760   0.687   11    -8.378     0       0.0422      0.000124
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
sludge_df.to_csv('sludge.csv')

# %% [markdown]
# ## doom

# %%
'5uTeekyMonHm8Ldh7U4j0A'
# Out:
# '5uTeekyMonHm8Ldh7U4j0A'

# %%
doom = get_playlist_tracks('Spotify','5uTeekyMonHm8Ldh7U4j0A')
doom_ids = []
for i in doom:
    doom_ids.append(i['track']['id'])
    
chunk = 100 
doom_ids_chopped = [doom_ids[i:i+chunk] for i in range(0,len(doom_ids),100)]

doom_af = []
for i in doom_ids_chopped:
    try:
        doom_af.extend(sp.audio_features(i))
    except:
        pass
doom_df = pd.DataFrame(doom_af)
doom_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.2290   0.704    9    -4.692     1       0.0342      0.000135
# 1          0.2560   0.831    1   -10.269     0       0.0964      0.001090
# 2          0.2610   0.877    9    -8.055     0       0.0770      0.000512
# 3          0.3670   0.614    6   -11.960     1       0.0386      0.019700
# 4          0.2720   0.775    0    -9.766     0       0.0444      0.008560
# ..            ...     ...  ...       ...   ...          ...           ...
# 161        0.0622   0.368    3    -8.072     0       0.0456      0.193000
# 162        0.4680   0.829   11    -8.667     1       0.0448      0.049400
# 163        0.2880   0.712    5    -6.544     1       0.0867      0.060300
# 164        0.1100   0.857    3    -4.236     0       0.0591      0.000016
# 165        0.3790   0.726    3    -4.935     0       0.0332      0.000193
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
doom_df.to_csv('doom.csv')

# %%
##screamo

# %%
'7x7GU1XXWIvMLQN9u6IiCX'
# Out:
# '7x7GU1XXWIvMLQN9u6IiCX'

# %%
screamo = get_playlist_tracks('Spotify','7x7GU1XXWIvMLQN9u6IiCX')
screamo_ids = []
for i in screamo:
    screamo_ids.append(i['track']['id'])
    
chunk = 100 
screamo_ids_chopped = [screamo_ids[i:i+chunk] for i in range(0,len(screamo_ids),100)]

screamo_af = []
for i in screamo_ids_chopped:
    try:
        screamo_af.extend(sp.audio_features(i))
    except:
        pass
screamo_df = pd.DataFrame(screamo_af)
screamo_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.419   0.932    1    -3.604     0       0.1060      0.001710
# 1           0.371   0.960    2    -3.163     1       0.0973      0.000034
# 2           0.522   0.880    5    -4.104     0       0.0633      0.000094
# 3           0.489   0.741   11    -7.406     0       0.0624      0.041400
# 4           0.226   0.905    8    -3.239     1       0.0942      0.050900
# ..            ...     ...  ...       ...   ...          ...           ...
# 133         0.513   0.958    2    -4.560     0       0.1610      0.000254
# 134         0.206   0.908    9    -4.291     0       0.1040      0.000033
# 135         0.217   0.949    0    -5.398     0       0.3390      0.031600
# 136         0.354   0.921    0    -5.265     1       0.0895      0.000112
# 137         0.394   0.799   11    -4.388     0       0.0699      0.003380
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
screamo_df.to_csv('screamo.csv')

# %%
#uk_drill

# %%
'1vaq3aKe69CMw3sXL1ezKN'
# Out:
# '1vaq3aKe69CMw3sXL1ezKN'

# %%
uk_drill = get_playlist_tracks('Spotify','1vaq3aKe69CMw3sXL1ezKN')
uk_drill_ids = []
for i in uk_drill:
    uk_drill_ids.append(i['track']['id'])
    
chunk = 100 
uk_drill_ids_chopped = [uk_drill_ids[i:i+chunk] for i in range(0,len(uk_drill_ids),100)]

uk_drill_af = []
for i in uk_drill_ids_chopped:
    try:
        uk_drill_af.extend(sp.audio_features(i))
    except:
        pass
uk_drill_df = pd.DataFrame(uk_drill_af)
uk_drill_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.778   0.590   11   -12.055     0        0.362         0.547
# 1           0.887   0.501    1    -7.982     1        0.419         0.498
# 2           0.815   0.746    8    -8.917     1        0.336         0.228
# 3           0.805   0.548   11    -9.504     0        0.321         0.526
# 4           0.693   0.665    1    -9.352     1        0.344         0.179
# ..            ...     ...  ...       ...   ...          ...           ...
# 124         0.819   0.264    1   -17.555     1        0.556         0.272
# 125         0.708   0.420   10    -8.589     0        0.444         0.144
# 126         0.899   0.639    7    -9.071     1        0.465         0.484
# 127         0.809   0.268    8   -15.493     1        0.433         0.774
# 128         0.915   0.516    2    -9.615     1        0.387         0.225
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
uk_drill_df.to_csv('uk_drill.csv')

# %%
##no_wave

# %%
'3GUW7gOyTyn5awv5sWCEa6'
# Out:
# '3GUW7gOyTyn5awv5sWCEa6'

# %%
no_wave = get_playlist_tracks('Spotify','3GUW7gOyTyn5awv5sWCEa6')
no_wave_ids = []
for i in no_wave:
    no_wave_ids.append(i['track']['id'])
    
chunk = 100 
no_wave_ids_chopped = [no_wave_ids[i:i+chunk] for i in range(0,len(no_wave_ids),100)]

no_wave_af = []
for i in no_wave_ids_chopped:
    try:
        no_wave_af.extend(sp.audio_features(i))
    except:
        pass
no_wave_df = pd.DataFrame(no_wave_af)
no_wave_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.403   0.891    1    -8.907     0       0.1390      0.005250
# 1           0.448   0.814    4   -10.641     0       0.0761      0.020900
# 2           0.244   0.911    0    -8.142     1       0.0816      0.000197
# 3           0.556   0.754    8    -3.560     1       0.2060      0.003740
# 4           0.437   0.926   11    -7.581     0       0.0797      0.189000
# ..            ...     ...  ...       ...   ...          ...           ...
# 139         0.410   0.667    6    -8.043     1       0.0315      0.927000
# 140         0.702   0.671    7    -9.123     1       0.0433      0.124000
# 141         0.592   0.508    2   -11.167     1       0.0399      0.783000
# 142         0.543   0.730    7    -6.623     0       0.0302      0.098600
# 143         0.556   0.618    7    -8.314     1       0.0358      0.000542
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
no_wave_df.to_csv('no_wave.csv')

# %% [markdown]
# ## pop

# %%
'1z9nITIlc0tEaCwHaaeD66'
# Out:
# '1z9nITIlc0tEaCwHaaeD66'

# %%
pop = get_playlist_tracks('Spotify','1z9nITIlc0tEaCwHaaeD66')
pop_ids = []
for i in pop:
    pop_ids.append(i['track']['id'])
    
chunk = 100 
pop_ids_chopped = [pop_ids[i:i+chunk] for i in range(0,len(pop_ids),100)]

pop_af = []
for i in pop_ids_chopped:
    try:
        pop_af.extend(sp.audio_features(i))
    except:
        pass
pop_df = pd.DataFrame(pop_af)
pop_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.426   0.584    1    -5.293     1       0.2960       0.03830
# 1           0.892   0.714    4    -6.055     0       0.1410       0.20100
# 2           0.759   0.699    0    -5.745     0       0.0307       0.20200
# 3           0.778   0.824   10    -5.892     0       0.0707       0.28400
# 4           0.845   0.768    6    -5.448     1       0.1880       0.00733
# ..            ...     ...  ...       ...   ...          ...           ...
# 250         0.676   0.695   11   -13.395     0       0.0392       0.32600
# 251         0.620   0.573    0   -11.893     1       0.0423       0.27100
# 252         0.731   0.738    9    -8.125     0       0.0377       0.18400
# 253         0.699   0.692   11   -13.045     1       0.0456       0.00979
# 254         0.899   0.421    4   -11.238     1       0.0511       0.20200
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
pop_df.to_csv('pop.csv')

# %% [markdown]
# ## jazz

# %%
'37i9dQZF1DXbITWG1ZJKYt'

# %%
jazz = get_playlist_tracks('Spotify','37i9dQZF1DXbITWG1ZJKYt')
jazz_ids = []
for i in jazz:
    jazz_ids.append(i['track']['id'])
    
chunk = 100 
jazz_ids_chopped = [jazz_ids[i:i+chunk] for i in range(0,len(jazz_ids),100)]

jazz_af = []
for i in jazz_ids_chopped:
    try:
        jazz_af.extend(sp.audio_features(i))
    except:
        pass
jazz_df = pd.DataFrame(jazz_af)
jazz_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.271   0.165    5   -20.652     1       0.0351         0.729
# 1           0.349   0.182    5   -13.507     1       0.0310         0.920
# 2           0.454   0.260    8   -13.193     0       0.0401         0.539
# 3           0.262   0.356    0    -8.031     0       0.0303         0.613
# 4           0.653   0.149   10   -17.866     0       0.0392         0.867
# ..            ...     ...  ...       ...   ...          ...           ...
# 245         0.458   0.155   10   -17.853     1       0.0405         0.908
# 246         0.649   0.271    5   -15.198     0       0.0498         0.708
# 247         0.350   0.607    5   -11.141     0       0.0498         0.794
# 248         0.370   0.586    5   -13.468     0       0.0581         0.485
# 249         0.355   0.152    5   -14.864     0       0.0401         0.924
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
jazz_df.to_csv('jazz.csv')

# %% [markdown]
# ## blues

# %%
'37i9dQZF1DWSKpvyAAcaNZ'
# Out:
# '37i9dQZF1DWSKpvyAAcaNZ'

# %%
blues = get_playlist_tracks('Spotify','37i9dQZF1DWSKpvyAAcaNZ')
blues_ids = []
for i in blues:
    blues_ids.append(i['track']['id'])
    
chunk = 100 
blues_ids_chopped = [blues_ids[i:i+chunk] for i in range(0,len(blues_ids),100)]

blues_af = []
for i in blues_ids_chopped:
    try:
        blues_af.extend(sp.audio_features(i))
    except:
        pass
blues_df = pd.DataFrame(blues_af)
blues_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.624   0.420    9    -7.471     1       0.0373       0.64000
# 1           0.640   0.700    0    -6.129     1       0.0308       0.03970
# 2           0.463   0.700    9    -6.313     1       0.0414       0.19400
# 3           0.753   0.577    2    -7.420     1       0.1390       0.18100
# 4           0.754   0.520    7    -7.488     1       0.0682       0.61300
# ..            ...     ...  ...       ...   ...          ...           ...
# 160         0.551   0.695    0    -7.111     1       0.0323       0.18100
# 161         0.700   0.920    1    -2.977     1       0.1650       0.23200
# 162         0.520   0.742    9    -4.085     1       0.0352       0.00511
# 163         0.628   0.662    0    -6.579     1       0.0338       0.12700
# 164         0.263   0.745    0   -10.297     1       0.0811       0.00498
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
blues_df.to_csv('blues.csv')

# %% [markdown]
# ## hardcore

# %%
'6BKzbBdCqjda3Smsrjdkql'
# Out:
# '6BKzbBdCqjda3Smsrjdkql'

# %%
hardcore = get_playlist_tracks('Spotify','6BKzbBdCqjda3Smsrjdkql')
hardcore_ids = []
for i in hardcore:
    hardcore_ids.append(i['track']['id'])
    
chunk = 100 
hardcore_ids_chopped = [hardcore_ids[i:i+chunk] for i in range(0,len(hardcore_ids),100)]

hardcore_af = []
for i in hardcore_ids_chopped:
    try:
        hardcore_af.extend(sp.audio_features(i))
    except:
        pass
hardcore_df = pd.DataFrame(hardcore_af)
hardcore_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.461   0.888    2    -6.092     1       0.0898      0.013200
# 1           0.659   0.954   10    -5.088     0       0.0740      0.064800
# 2           0.379   0.783   10    -4.539     1       0.0905      0.001630
# 3           0.440   0.996    2    -1.776     0       0.0483      0.006960
# 4           0.531   0.904    7    -2.218     1       0.0867      0.000149
# ..            ...     ...  ...       ...   ...          ...           ...
# 96          0.264   0.884    8    -5.590     1       0.1640      0.006100
# 97          0.452   0.877    6    -1.412     0       0.0437      0.032000
# 98          0.425   0.976    7    -0.329     0       0.1810      0.077700
# 99          0.620   0.996    1    -0.523     1       0.2920      0.056800
# 100         0.577   0.887    8    -3.105     1       0.0523      0.020200
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
hardcore_df.to_csv('hardcode.csv')

# %% [markdown]
# ## disco

# %%
'0aSvbpDVaEBTv9dPiXrndk'

# %%
disco = get_playlist_tracks('Spotify','0aSvbpDVaEBTv9dPiXrndk')
disco_ids = []
for i in disco:
    disco_ids.append(i['track']['id'])
    
chunk = 100 
disco_ids_chopped = [disco_ids[i:i+chunk] for i in range(0,len(disco_ids),100)]

disco_af = []
for i in disco_ids_chopped:
    try:
        disco_af.extend(sp.audio_features(i))
    except:
        pass
disco_df = pd.DataFrame(disco_af)
disco_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.763   0.777    5    -6.932     0       0.0364        0.2810
# 1           0.832   0.553    7   -13.705     1       0.0487        0.0422
# 2           0.872   0.946    4    -3.105     1       0.0656        0.0502
# 3           0.697   0.832    9    -7.264     1       0.0298        0.1680
# 4           0.723   0.969    6    -4.516     1       0.1420        0.0643
# ..            ...     ...  ...       ...   ...          ...           ...
# 214         0.936   0.717    4    -5.131     0       0.2040        0.0142
# 215         0.649   0.848    6    -7.673     0       0.0351        0.0149
# 216         0.806   0.926    7    -3.470     1       0.0405        0.1430
# 217         0.718   0.757    2    -7.444     1       0.0322        0.0195
# 218         0.409   0.946    2    -2.878     1       0.0548        0.2350
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
disco_df.to_csv('disco.csv')

# %% [markdown]
# ## ambient

# %%
'37i9dQZF1DWUrPBdYfoJvz'

# %%
ambient = get_playlist_tracks('Spotify','37i9dQZF1DWUrPBdYfoJvz')
ambient_ids = []
for i in ambient:
    ambient_ids.append(i['track']['id'])
    
chunk = 100 
ambient_ids_chopped = [ambient_ids[i:i+chunk] for i in range(0,len(ambient_ids),100)]

ambient_af = []
for i in ambient_ids_chopped:
    try:
        ambient_af.extend(sp.audio_features(i))
    except:
        pass
ambient_df = pd.DataFrame(ambient_af)
ambient_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.2570  0.0906    8   -25.381     1       0.0700         0.932
# 1          0.1590  0.0710    6   -27.109     0       0.0409         0.911
# 2          0.0814  0.0293    0   -25.421     1       0.0408         0.982
# 3          0.1960  0.0236    5   -25.493     0       0.0429         0.528
# 4          0.1790  0.2490    0   -19.918     1       0.0405         0.820
# ..            ...     ...  ...       ...   ...          ...           ...
# 117        0.1290  0.2450    4   -22.343     0       0.0400         0.858
# 118        0.2010  0.0941    5   -30.788     1       0.0411         0.972
# 119        0.0643  0.0704    7   -24.653     1       0.0390         0.654
# 120        0.4970  0.5370    6   -23.866     1       0.0487         0.924
# 121        0.2300  0.1680    3   -22.653     1       0.0481         0.988
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
ambient_df.to_csv('ambient.csv')

# %% [markdown]
# ## drone

# %%
'6qQ0yDdtWIVIrYcwD2Synx'

# %%
drone = get_playlist_tracks('Spotify','6qQ0yDdtWIVIrYcwD2Synx')
drone_ids = []
for i in drone:
    drone_ids.append(i['track']['id'])
    
chunk = 100 
drone_ids_chopped = [drone_ids[i:i+chunk] for i in range(0,len(drone_ids),100)]

drone_af = []
for i in drone_ids_chopped:
    try:
        drone_af.extend(sp.audio_features(i))
    except:
        pass
drone_df = pd.DataFrame(drone_af)
drone_df
# Out:
#      danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.1090  0.00822    1   -28.425     1       0.0529         0.942
# 1          0.0878  0.33000   11   -15.884     1       0.0467         0.845
# 2          0.2440  0.22400    4   -20.608     0       0.0371         0.778
# 3          0.0689  0.37100    1   -15.942     0       0.0537         0.823
# 4          0.1230  0.18700   11   -19.279     1       0.0438         0.988
# ..            ...      ...  ...       ...   ...          ...           ...
# 278        0.1600  0.30000    6   -20.727     0       0.0471         0.988
# 279        0.0935  0.17400    0   -16.123     0       0.0886         0.637
# 280        0.1690  0.06650    7   -16.754     1       0.0588         0.968
# 281        0.1480  0.02720    7   -16.655     1       0.0787         0.370
# 282        0.1900  0.13600    7   -22.233     1       0.0514         0.939
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
drone_df.to_csv('drone.csv')

# %% [markdown]
# ## big df

# %%
merged_df = pd.concat([no_wave_df, uk_drill_df,screamo_df,doom_df,sludge_df,post_punk_df,indie_df,
                       post_metal_df,surfrock_df, jazz_df, blues_df, hardcore_df, disco_df,
                       ambient_df, drone_df,
                       pop_df,vaporwave_df,stoner_rock_df], ignore_index=True)

# %%
merged_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.403   0.891    1    -8.907     0       0.1390      0.005250
# 1            0.448   0.814    4   -10.641     0       0.0761      0.020900
# 2            0.244   0.911    0    -8.142     1       0.0816      0.000197
# 3            0.556   0.754    8    -3.560     1       0.2060      0.003740
# 4            0.437   0.926   11    -7.581     0       0.0797      0.189000
# ...            ...     ...  ...       ...   ...          ...           ...
# 3237         0.311   0.832    7    -5.139     1       0.0368      0.000029
# 3238         0.380   0.691    1    -7.790     0       0.0335      0.001560
# 3239         0.168   0.813    1    -6.856     1       0.0510      0.000361
# 3240         0.460   0.756    5    -9.251     0       0.0426      0.037100
# 3241         0.538   0.863    4    -6.123     0       0.1390      0.004950
#
# ...

# %%
merged_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.403   0.891    1    -8.907     0       0.1390      0.005250
# 1            0.448   0.814    4   -10.641     0       0.0761      0.020900
# 2            0.244   0.911    0    -8.142     1       0.0816      0.000197
# 3            0.556   0.754    8    -3.560     1       0.2060      0.003740
# 4            0.437   0.926   11    -7.581     0       0.0797      0.189000
# ...            ...     ...  ...       ...   ...          ...           ...
# 3237         0.311   0.832    7    -5.139     1       0.0368      0.000029
# 3238         0.380   0.691    1    -7.790     0       0.0335      0.001560
# 3239         0.168   0.813    1    -6.856     1       0.0510      0.000361
# 3240         0.460   0.756    5    -9.251     0       0.0426      0.037100
# 3241         0.538   0.863    4    -6.123     0       0.1390      0.004950
#
# ...

# %%
merged_df.to_csv('genres.csv')
